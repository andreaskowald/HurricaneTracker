# %%
import os
import requests
import csv
import re
import pandas as pd

# https://www.ndbc.noaa.gov/data/stations/

# function to download station table
def download_station_table(data_url, destination_name):
    station_table_url= os.path.join(data_url,  destination_name)
    response = requests.get(station_table_url)
    if response.status_code == 200:
        with open("../data/station_table.txt", "wb") as file:
            file.write(response.content)
        print(f"Downloaded data for station table")
    else:
        print(f"Failed to download data for station table")

# %%
with open("../data/station_table.txt", "r") as file:
    data = file.read()

# %%
pattern = r'([A-Za-z0-9]+)\|([^|]*)\|([^|]*)\|([^|]*)\|([^|]*)\|([^|]*)\|.*?(\d+\.\d+)\s*([NS])\s*(\d+\.\d+)\s*([EW]).*?\|([^|]*)\|([^|]*)\|([^|^\n]*)'

# Use regular expressions to find all matches
matches = re.findall(pattern, data)

# Create a list to store the data
data_list = []

# Convert the matches into a list of dictionaries
for station_id, owner, ttype, hull, name, payload, lat, lat_dir, lon, lon_dir, timezone, forecast, note in matches:
    latitude = float(lat) if lat_dir == 'N' else -float(lat)
    longitude = float(lon) if lon_dir == 'E' else -float(lon)
    data_list.append({
        'station_id': station_id,
        'owner': owner,
        'ttype': ttype,
        'hull': hull,
        'name': name,
        'payload': payload,
        'latitude': latitude,
        'longitude': longitude,
        'timezone': timezone,
        'forecast': forecast,
        'note': note
    })

# Create a Pandas DataFrame from the list of dictionaries
df = pd.DataFrame(data_list)

# %% [markdown]
# df.head(10)

# %%
df.to_parquet('../data/station_table.parquet')

# %%
parquet = pd.read_parquet('../data/station_table.parquet')

# %%
parquet.head(5)
# Out:
#   station_id owner            ttype    hull                         name  \
# 0      0y2w3    CG  Weather Station          Sturgeon Bay CG Station, WI
# 1      13001    PR       Atlas Buoy  PM-595                 NE Extension
# 2      13002    PR       Atlas Buoy                         NE Extension
# 3      13008    PR       Atlas Buoy  PM-531                       Reggae
# 4      13009    PR       Atlas Buoy  PM-533                      Lambada
#
#   payload  latitude  longitude timezone forecast note
# 0            44.794    -87.313        C
# 1            12.000    -23.000
# 2            21.000    -23.000
# 3            15.000    -38.000
# 4             8.000    -38.000

# %% [markdown]
# # Florida: look at buoys 20.000 < lat < 32.336, -87.500 < lon < -66.000

# %%
df[(df['latitude'] < 32.336) & (df['latitude'] > 20.000) & (df['longitude'] > -87.500) & (df['longitude'] < -66.000)]
# Out:
#      station_id owner                  ttype  hull  \
# 115       41002     N      3-meter foam buoy  3D66
# 116       41003     N     6-meter NOMAD buoy
# 118       41005     N     6-meter NOMAD buoy
# 119       41006     N     6-meter NOMAD buoy
# 121       41008     N    3-meter discus buoy  3D36
# ...         ...   ...                    ...   ...
# 1777      venf1     N          C-MAN Station
# 1805      wiwf1    NP  Water Quality Station
# 1812      wplf1    NP  Water Quality Station
# 1815      wrbf1    NP  Water Quality Station
# 1818      wwef1    NP  Water Quality Station
#
#                                                 name        payload  latitude  \
# 115   SOUTH HATTERAS - 225 NM South of Cape Hatteras  SCOOP payload    31.759
# 116                                                   MVXII payload    30.400
# 118                                                    GSBP payload    31.700
# 119                                                    GSBP payload    29.300
# 121     GRAYS REEF - 40 NM Southeast of Savannah, GA  SCOOP payload    31.400
# ...                                              ...            ...       ...
# 1777                                      Venice, FL   ARES payload    27.072
# 1805                                 Willy Willy, FL                   25.587
# 1812                                Watson Place, FL                   25.710
# 1815                               Whipray Basin, FL                   25.072
# 1818                         Whitewater Bay-East, FL                   25.232
#
#       longitude timezone      forecast  \
# 115     -74.936        E  FZNT22.KWBC
# 116     -80.100        E
# 118     -79.700        E
# 119     -77.400        E
# 121     -80.866        E  FZUS52.KCHS
# ...         ...      ...           ...
# 1777    -82.453        E  FZUS52.KTBW
# 1805    -81.044        E
# 1812    -81.249        E  FZUS52.KMFL
# 1815    -80.735        E  FZUS52.KKEY
# 1818    -80.938        E  FZUS52.KMFL
#
#                                                    note
# 115   Right whales are active off SC from November t...
# 116                                     (formerly eb05)
# 118
# 119
# 121   <p>This buoy is located in <a href="http://www...
# ...                                                 ...
# 1777
# 1805  Water levels are referenced to local datums.&n...
# 1812  Water levels are referenced to local datums.&n...
# 1815  Water levels are referenced to local datums.&n...
# 1818
#
# [190 rows x 11 columns]
